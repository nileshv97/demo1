# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# The Boston Housing Dataset
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per $10,000
# PTRATIO - pupil-teacher ratio by town
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT - % lower status of the population
# MEDV - Median value of owner-occupied homes in $1000's

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data =pd.read_csv('housing.csv', header=None, delimiter=r"\s+", names=column_names)
data.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data.isnull().sum()/len(data)*100
# Out:
# CRIM       0.0
# ZN         0.0
# INDUS      0.0
# CHAS       0.0
# NOX        0.0
# RM         0.0
# AGE        0.0
# DIS        0.0
# RAD        0.0
# TAX        0.0
# PTRATIO    0.0
# B          0.0
# LSTAT      0.0
# MEDV       0.0
# dtype: float64

# %%
#note- no null values let go distribution

# %%
data.hist(bins=50, figsize=(15, 15))
# Out:
# array([[<AxesSubplot:title={'center':'CRIM'}>,
#         <AxesSubplot:title={'center':'ZN'}>,
#         <AxesSubplot:title={'center':'INDUS'}>,
#         <AxesSubplot:title={'center':'CHAS'}>],
#        [<AxesSubplot:title={'center':'NOX'}>,
#         <AxesSubplot:title={'center':'RM'}>,
#         <AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'DIS'}>],
#        [<AxesSubplot:title={'center':'RAD'}>,
#         <AxesSubplot:title={'center':'TAX'}>,
#         <AxesSubplot:title={'center':'PTRATIO'}>,
#         <AxesSubplot:title={'center':'B'}>],
#        [<AxesSubplot:title={'center':'LSTAT'}>,
#         <AxesSubplot:title={'center':'MEDV'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
plt.figure(figsize=(15,9),dpi=200)
plt_number=1
for  column in data:
    if plt_number<=14:
        ax=plt.subplot(4,4,plt_number)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=15)
    plt_number +=1
plt.tight_layout()
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15,15))
dplot=sns.heatmap(data.corr(),annot=True,cmap='Blues')
plt.show()

# %%
for col in data.columns:
        data.plot.scatter(x=col,y='MEDV')

# %%
plt.figure(figsize=(20, 15))
features = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']
target = data['MEDV']
for i, col in enumerate(features):
    plt.subplot(3, len(features)/2 , i+1)
    x = data[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.xlabel(col)
    plt.ylabel('MEDV')

# %%
print(X.shape)
print(y.shape)
# Out:
# (506, 12)
# (506,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = data.drop(["MEDV"], axis=1).values
y= data["MEDV"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)
print(len(X_train), "train set + ", len(X_test), "test set")
# Out:
# 354 train set +  152 test set

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (354, 13)
# (354,)
# (152, 13)
# (152,)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
r2 = lr.score(X_test, y_test)
rmse = (np.sqrt(mean_squared_error(y_test, y_pred)))

# %%
print("The model performance is")
print("--------------------------------------")
print('R2 score is {}'.format(r2))
print('RMSE is {}'.format(rmse))
print("\n")
# Out:
# The model performance is
# --------------------------------------
# R2 score is 0.711226005748496
# RMSE is 4.638689926172797

# %% [raw]
# #lets further  improve it as r squre is 71%  which is not good not bad

# %%
print(X.shape)
print(y.shape)
# Out:
# (506, 12)
# (506,)

# %% [markdown]
# # scaling the data with StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
data_scaled=pd.DataFrame(sc.fit_transform(data),columns=column_names)

# %%
X = data_scaled.drop(["MEDV"], axis=1).values
y= data_scaled["MEDV"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)
print(len(X_train), "train set + ", len(X_test), "test set")
# Out:
# 354 train set +  152 test set

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
Intercept=lr.intercept_.mean()
Coefficients=lr.coef_.mean()
y=Intercept + X*Coefficients

# %%
r2 = lr.score(X_test, y_test)
rmse = (np.sqrt(mean_squared_error(y_test, y_pred)))
print("The model performance is")
print("--------------------------------------")
print('R2 score is {}'.format(r2))
print('RMSE is {}'.format(rmse))
print("\n")
# Out:
# The model performance is
# --------------------------------------
# R2 score is 0.7112260057484925
# RMSE is 0.5048633105556651

# %%
#note-scaling has reduced the RMSE which look better now

# %% [markdown]
# # polynomial regression

# %%
#fitting the polynomial regression model to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=1)
X= data.iloc[:,1:14].values
y= data.iloc[:,13].values
X_trainp, X_testp, y_trainp, y_testp = train_test_split(X_poly,y, test_size=0.3, random_state=42)

X_trainp=poly_reg.fit_transform(X_trainp)
X_testp=poly_reg.fit_transform(X_testp)


poly_reg.fit(X_trainp,y_trainp)
lin_reg2=LinearRegression()
lin_reg2.fit(X_trainp,y_trainp)
print(X_trainp.shape)
print(X_testp.shape)
print(y_trainp.shape)
print(y_testp.shape)
y_ploypred=lin_reg2.predict(X_testp)
print(y_ploypred.shape)
# Out:
# (354, 14)
# (152, 14)
# (354,)
# (152,)
# (152,)

# %%
r2 = lin_reg2.score(X_testp, y_testp)
rmse = (np.sqrt(mean_squared_error(y_testp, y_ploypred)))
print("The model performance is")
print("--------------------------------------")
print('R2 score is {}'.format(r2))
print('RMSE is {}'.format(rmse))
print("\n")
# Out:
# The model performance is
# --------------------------------------
# R2 score is 0.7150613796634305
# RMSE is 4.607782400256655

# %% [markdown]
# # polynomial regression with scaling

# %%
from sklearn.preprocessing import MinMaxScaler
minmax=MinMaxScaler()
X=data.drop(columns='MEDV')
y=data['MEDV']
x_scaler=minmax.fit_transform(X)

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaler,y,test_size=0.2,random_state=2)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_n = PolynomialFeatures(degree=2) # Select degree
X_train_poly = poly_n.fit_transform(x_train)
X_test_poly = poly_n.transform(x_test)

# %%
model1=LinearRegression()
model1.fit(X_train_poly,y_train)
# Out:
# LinearRegression()

# %%
y_predpt=model1.predict(X_train_poly)
y_predp=model1.predict(X_test_poly)

# %%
model1.score(X_train_poly,y_train)
# Out:
# 0.9295925088768032

# %%
model1.score(X_test_poly,y_test)
# Out:
# 0.8963635527280771

# %%
#for test data
r2 = model1.score(X_test_poly, y_test)
rmse = (np.sqrt(mean_squared_error(y_test, y_predp)))
print("The model performance is")
print("--------------------------------------")
print('R2 score is {}'.format(r2))
print('RMSE is {}'.format(rmse))
print("\n")
# Out:
# The model performance is
# --------------------------------------
# R2 score is 0.8963635527280771
# RMSE is 2.944519011172811

# %%
#for train data
r2 = model1.score(X_train_poly, y_train)
rmse = (np.sqrt(mean_squared_error(y_train, y_predpt)))
print("The model performance is")
print("--------------------------------------")
print('R2 score is {}'.format(r2))
print('RMSE is {}'.format(rmse))
print("\n")
# Out:
# The model performance is
# --------------------------------------
# R2 score is 0.9295925088768032
# RMSE is 2.440154605177944

# %%
#here we can say that our model is givin 89% acuracy 
#you can further go for gridsearcv and ensembles techniques or may be pipeline also

# %% [markdown]
# # Ridge

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_scaled=sc.fit_transform(X)
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import Ridge
model = Ridge()
model.fit(x_train,y_train)
model.score(x_test, y_test)
# Out:
# 0.7791514800552007

# %% [markdown]
# # lasso

# %%
from sklearn.linear_model import LassoCV
model = LassoCV()
model.fit(x_train,y_train)
model.score(x_test, y_test)

# %% [markdown]
# # ElasticNet

# %%
from sklearn.linear_model import ElasticNet
model = ElasticNet()
model.fit(x_train,y_train)
model.score(x_test, y_test)
# Out:
# 0.7171753501749457
